# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Parth Suthar\Desktop\CT604E-N Machine Learning\Datasets\Connect_Mobile__Attrition_Data_file.csv")

# %%
df.head()
# Out:
#    active_cust  income  expenditure  months_on_network  Num_complaints  \
# 0            0    1586       1268.8                 85               4
# 1            0    1581       1264.8                 85               4
# 2            0    1594       1275.2                 82               4
# 3            0    1594       1275.2                 82               4
# 4            1    1609       1287.2                 80               4
#
#    number_plan_changes  relocated  monthly_bill  technical_issues_per_month  \
# 0                    1          0           121                           4
# 1                    1          0           133                           4
# 2                    1          0           118                           4
# 3                    1          0           123                           4
# 4                    1          0           177                           4
#
#    Speed_test_result
# 0                 85
# 1                 85
# ...

# %%
df.columns
# Out:
# Index(['active_cust', 'income', 'expenditure', 'months_on_network',
#        'Num_complaints', 'number_plan_changes', 'relocated', 'monthly_bill',
#        'technical_issues_per_month', 'Speed_test_result'],
#       dtype='object')

# %%
df.shape
# Out:
# (100000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   active_cust                 100000 non-null  int64
#  1   income                      100000 non-null  int64
#  2   expenditure                 100000 non-null  float64
#  3   months_on_network           100000 non-null  int64
#  4   Num_complaints              100000 non-null  int64
#  5   number_plan_changes         100000 non-null  int64
#  6   relocated                   100000 non-null  int64
#  7   monthly_bill                100000 non-null  int64
#  8   technical_issues_per_month  100000 non-null  int64
#  9   Speed_test_result           100000 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 7.6 MB

# %%
df.describe()
# Out:
#          active_cust         income    expenditure  months_on_network  \
# count  100000.000000  100000.000000  100000.000000      100000.000000
# mean        0.578590    1855.279910    1409.669662          58.402450
# std         0.493787    2712.385257    2174.330870          18.643736
# min         0.000000    1130.000000     904.000000         -20.000000
# 25%         0.000000    1674.000000    1248.650000          47.000000
# 50%         1.000000    1805.000000    1358.400000          56.000000
# 75%         1.000000    1907.000000    1494.400000          70.000000
# max         1.000000  229821.000000  183856.800000         449.000000
#
#        Num_complaints  number_plan_changes      relocated   monthly_bill  \
# count   100000.000000        100000.000000  100000.000000  100000.000000
# mean         4.012840             1.385410       0.123480      95.816450
# std          0.285265             1.617101       0.328989      50.161327
# ...

# %%
sns.countplot(df['active_cust'])
# Out:
# <AxesSubplot:xlabel='active_cust', ylabel='count'>

# %%
df['active_cust'].value_counts()
# Out:
# 1    57859
# 0    42141
# Name: active_cust, dtype: int64

# %% [markdown]
# # Income And Expenditure

# %% [markdown]
# Customers with less savings will be more deliberate to leave the subscription. Thus, adding savings column to analyse the impact of expenditure and income.

# %%
df['savings'] = df['income']-df['expenditure']

# %%
df.columns
# Out:
# Index(['active_cust', 'income', 'expenditure', 'months_on_network',
#        'Num_complaints', 'number_plan_changes', 'relocated', 'monthly_bill',
#        'technical_issues_per_month', 'Speed_test_result', 'savings'],
#       dtype='object')

# %%
df.head()
# Out:
#    active_cust  income  expenditure  months_on_network  Num_complaints  \
# 0            0    1586       1268.8                 85               4
# 1            0    1581       1264.8                 85               4
# 2            0    1594       1275.2                 82               4
# 3            0    1594       1275.2                 82               4
# 4            1    1609       1287.2                 80               4
#
#    number_plan_changes  relocated  monthly_bill  technical_issues_per_month  \
# 0                    1          0           121                           4
# 1                    1          0           133                           4
# 2                    1          0           118                           4
# 3                    1          0           123                           4
# 4                    1          0           177                           4
#
#    Speed_test_result  savings
# 0                 85    317.2
# ...

# %%
df0 = df[df['active_cust'] == 0]
df0.shape
# Out:
# (42141, 11)

# %%
df0.describe()
# Out:
#        active_cust        income   expenditure  months_on_network  \
# count      42141.0  42141.000000  42141.000000       42141.000000
# mean           0.0   1851.463658   1419.705083          54.293016
# std            0.0    175.059696    185.928915          15.649477
# min            0.0   1241.000000    986.050000          -6.000000
# 25%            0.0   1741.000000   1281.600000          47.000000
# 50%            0.0   1848.000000   1438.400000          52.000000
# 75%            0.0   1913.000000   1515.200000          62.000000
# max            0.0   5537.000000   4429.600000         235.000000
#
#        Num_complaints  number_plan_changes     relocated  monthly_bill  \
# count    42141.000000         42141.000000  42141.000000  42141.000000
# mean         4.040744             1.921834      0.270378     99.352199
# std          0.303165             2.135027      0.444160     50.035114
# min          3.000000             0.000000      0.000000     30.000000
# ...

# %%
df1 = df[df['active_cust'] == 1]
df1.describe()
# Out:
#        active_cust         income    expenditure  months_on_network  \
# count      57859.0   57859.000000   57859.000000       57859.000000
# mean           1.0    1858.059438    1402.360468          61.395513
# std            0.0    3562.752659    2854.093733          20.028074
# min            1.0    1130.000000     904.000000         -20.000000
# 25%            1.0    1640.000000    1231.100000          48.000000
# 50%            1.0    1747.000000    1320.800000          61.000000
# 75%            1.0    1897.000000    1457.600000          75.000000
# max            1.0  229821.000000  183856.800000         449.000000
#
#        Num_complaints  number_plan_changes     relocated  monthly_bill  \
# count    57859.000000         57859.000000  57859.000000  57859.000000
# mean         3.992516             0.994711      0.016488     93.241224
# std          0.269677             0.915115      0.127345     50.096660
# ...

# %%
fig, axes = plt.subplots(1, 2,figsize=(12,5))
sns.distplot(ax = axes[0], x=df0['savings'])
axes[0].set_title(f"Savings of Non Active Customers")
axes[0].set_xlabel('savings')
sns.distplot(ax = axes[1], x=df1['savings'])
axes[1].set_title(f"Savings of Active Customers")
axes[1].set_xlabel('savings')
fig.tight_layout()

# %% [markdown]
# As can be seen in figure, most of the customers who left the subscription were the ones who had savings in range 300 - 450.

# %%
fig, axes = plt.subplots(1, 2,figsize=(12,5))
sns.stripplot(ax = axes[0], x=df0['savings'])
axes[0].set_xlabel('savings')
axes[0].set_title(f"Savings of Non Active Customers")
sns.stripplot(ax = axes[1], x=df1['savings'])
axes[1].set_title(f"Savings of Active Customers")
axes[1].set_xlabel('savings')
fig.tight_layout()

# %%
df[df['savings'] > 1000].shape
# Out:
# (68, 11)

# %% [markdown]
# There are 68 customers with savings more than 1000. 3 in non active customers and 65 in active customers. Such a small number of data about customers can affect the learning thus are outliers.

# %%
savings_outliers = df[df['savings'] > 1000]
savings_outliers[savings_outliers['months_on_network']< 0].shape
# Out:
# (68, 11)

# %% [markdown]
# The months_on_network values are negative which is not possible thus it is impute data.

# %%
df.drop(savings_outliers.index, inplace=True)
df.shape
# Out:
# (99932, 11)

# %% [markdown]
# # Months On Network

# %%
Negative_months = df[df['months_on_network'] < 0]
Negative_months.shape
# Out:
# (13, 11)

# %%
Negative_months
# Out:
#        active_cust  income  expenditure  months_on_network  Num_complaints  \
# 53552            1    4173       3338.4                 -1               4
# 58065            0    4193       3354.4                 -1               4
# 74084            1    4802       3841.6                 -4               4
# 74085            1    4802       3841.6                 -4               4
# 74086            1    4805       3844.0                 -4               4
# 74087            1    4806       3844.8                 -4               4
# 74088            1    4805       3844.0                 -3               4
# 74089            1    4804       3843.2                 -4               4
# 74090            1    4810       3848.0                 -3               4
# 74091            1    4802       3841.6                 -4               4
# 74092            1    4810       3848.0                 -3               4
# ...

# %%
df.drop(Negative_months.index, inplace = True)
df.shape
# Out:
# (99919, 11)

# %% [markdown]
# # Number Of Complaints

# %%
fig, axes = plt.subplots(1, 2,figsize=(12,5))
sns.distplot(ax = axes[0], x = df['Num_complaints'])
sns.countplot(ax = axes[1], x = df['Num_complaints'])
fig.tight_layout()

# %%
df0 = df[df['active_cust'] == 0]
df1 = df[df['active_cust'] == 1]

# %%
fig, axes = plt.subplots(figsize=(12,5))
sns.countplot(x = df['Num_complaints'], hue = df['active_cust'])
axes.set_title(f"Complaint of Non Active Customers(0) vs Active Customer(1)")
# Out:
# Text(0.5, 1.0, 'Complaint of Non Active Customers(0) vs Active Customer(1)')

# %% [markdown]
# Minimum number of complaints is 3 and most number of complaints is 4, so, the company had issues with maintaining the qualitity service.

# %%
df0['Num_complaints'].value_counts()
# Out:
# 4    38374
# 5     2650
# 3     1053
# 6       60
# Name: Num_complaints, dtype: int64

# %%
df1['Num_complaints'].value_counts()
# Out:
# 4    53592
# 3     2315
# 5     1868
# 6        7
# Name: Num_complaints, dtype: int64

# %% [markdown]
# # Internet speed of Connect-Mobile

# %%
df.describe()
# Out:
#         active_cust        income   expenditure  months_on_network  \
# count  99919.000000  99919.000000  99919.000000       99919.000000
# mean       0.578288   1819.726729   1381.166679          58.457931
# std        0.493835    227.754370    219.494386          18.548526
# min        0.000000   1130.000000    904.000000           0.000000
# 25%        0.000000   1674.000000   1248.650000          47.000000
# 50%        1.000000   1805.000000   1358.400000          56.000000
# 75%        1.000000   1906.000000   1493.600000          70.000000
# max        1.000000   4197.000000   3357.600000         449.000000
#
#        Num_complaints  number_plan_changes     relocated  monthly_bill  \
# count     99919.00000         99919.000000  99919.000000  99919.000000
# mean          4.01285             1.386153      0.123510     95.823717
# std           0.28538             1.616976      0.329023     50.178229
# min           3.00000             0.000000      0.000000     30.000000
# ...

# %%
sns.distplot(df['Speed_test_result'])
# Out:
# <AxesSubplot:xlabel='Speed_test_result', ylabel='Density'>

# %%
df0['Speed_test_result'].value_counts()
# Out:
# 77     6478
# 78     5479
# 81     4915
# 80     3630
# 76     3175
# 82     3029
# 75     2851
# 79     2655
# 87     2551
# 86     1912
# 83     1331
# 74     1284
# 85     1248
# 84     1022
# 88      429
# 73      103
# 89       10
# 327       4
# 72        3
# 326       3
# 94        2
# 332       2
# 93        2
# 95        2
# 231       1
# 135       1
# 103       1
# 325       1
# 101       1
# 322       1
# 143       1
# 200       1
# 105       1
# 114       1
# 117       1
# 277       1
# 121       1
# 218       1
# 92        1
# 125       1
# 98        1
# Name: Speed_test_result, dtype: int64

# %%
df1['Speed_test_result'].value_counts()
# Out:
# 86     10563
# 87      6233
# 85      6022
# 79      5871
# 80      5307
# 78      5029
# 83      3750
# 77      3351
# 84      3310
# 81      3243
# 82      2138
# 76      1552
# 88       795
# 75       213
# 332      122
# 89        88
# 72        67
# 73        49
# 74        33
# 90        25
# 91         7
# 92         3
# 98         1
# 101        1
# 97         1
# 104        1
# 126        1
# 105        1
# 108        1
# 94         1
# 112        1
# 93         1
# 96         1
# Name: Speed_test_result, dtype: int64

# %% [markdown]
# The internet speed mostly lies in range of 72-90 which is not a big variation. The customers recieving higher speed must have optic cable connection. So, It can be seen that most of the customers of company are using Wi-Fi.

# %% [markdown]
# # Monthly Bill

# %%
sns.distplot(df0['monthly_bill'])
# Out:
# <AxesSubplot:xlabel='monthly_bill', ylabel='Density'>

# %%
sns.distplot(df1['monthly_bill'])
# Out:
# <AxesSubplot:xlabel='monthly_bill', ylabel='Density'>

# %%
sns.distplot(df['monthly_bill'])
# Out:
# <AxesSubplot:xlabel='monthly_bill', ylabel='Density'>

# %% [markdown]
# There are 4 catagories of customers on the basis of usage per month. The catagories can be based on usage or the type of subscription. Most customer belong to the range of 30-60 monthly bill.

# %%
def categorize(bill):
    if (bill >=30 ) and (bill <= 60):
        return 'a'
    elif (bill >= 70) and (bill <= 95):
        return 'b'
    elif (bill >= 110) and (bill <= 140):
        return 'c'
    elif (bill >= 155) and (bill <= 185):
        return 'd'

# %%
df['monthly_bill'] = df['monthly_bill'].map(categorize)

# %%
df['monthly_bill'].astype('object')
# Out:
# 0        c
# 1        c
# 2        c
# 3        c
# 4        d
#         ..
# 99995    a
# 99996    a
# 99997    a
# 99998    a
# 99999    a
# Name: monthly_bill, Length: 99919, dtype: object

# %%
df['monthly_bill'].value_counts()
# Out:
# a    36262
# d    21750
# c    20959
# b    20948
# Name: monthly_bill, dtype: int64

# %% [markdown]
# # number_plan_changes

# %%
df['number_plan_changes'].value_counts()
# Out:
# 0    33173
# 1    28126
# 2    25756
# 3     7071
# 6     1474
# 7     1256
# 9      794
# 5      770
# 8      756
# 4      743
# Name: number_plan_changes, dtype: int64

# %%
sns.countplot(df['number_plan_changes'], hue = df['active_cust'])
# Out:
# <AxesSubplot:xlabel='number_plan_changes', ylabel='count'>

# %% [markdown]
# # Technical Issues Per Month

# %%
df['technical_issues_per_month'].value_counts()
# Out:
# 4    73916
# 1    20977
# 3     3221
# 2     1504
# 7      301
# Name: technical_issues_per_month, dtype: int64

# %%
sns.countplot(df['technical_issues_per_month'], hue = df['active_cust'])
# Out:
# <AxesSubplot:xlabel='technical_issues_per_month', ylabel='count'>

# %% [markdown]
# Most of the customers had to face 4 technical issues and atleast 1 technical issue per month. Thus, the service provide by company is unsatisfactory and could be the major reason to cancel the subscription or change the provider.

# %% [markdown]
# # Relocation

# %%
df['relocated'].value_counts()
# Out:
# 0    87578
# 1    12341
# Name: relocated, dtype: int64

# %%
sns.countplot(df['relocated'], hue = df['active_cust'])
# Out:
# <AxesSubplot:xlabel='relocated', ylabel='count'>

# %% [markdown]
# Very less customers have relocated.

# %% [markdown]
# 'Speed_test_result' and 'relocated' have no significant effect on attrition of customers. So, this features will not contribute in prediction of 'active_cust'. Thus, the features will be droped

# %% [markdown]
# # Dealing with Outliers

# %%
def outliers_of(feature):
    fig, axes = plt.subplots(1, 2,figsize=(12,5))
    sns.distplot(ax = axes[0], x = df[feature])
    sns.boxplot(ax = axes[1], x = df[feature])
    fig.tight_layout()

    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    Min_value = (Q1 - 1.5 * IQR)
    Max_value = (Q3 + 1.5 * IQR)
    print("Min value before which outlier exist: {}".format(Min_value))
    print("Max value after which outlier exist: {}".format(Max_value))

# %%
def remove_outliers(feature):
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    Min_value = (Q1 - 1.5 * IQR)
    Max_value = (Q3 + 1.5 * IQR)
    outliers = df[(df[feature] < Min_value) | (df[feature] > Max_value)]
    df.drop(outliers.index, inplace = True)
    print(f'Outliers of {feature} removed')

# %%
outliers_of('months_on_network')
# Out:
# Min value before which outlier exist: 12.5
# Max value after which outlier exist: 104.5

# %%
remove_outliers('months_on_network')
# Out:
# Outliers of months_on_network removed

# %%
outliers_of('Num_complaints')
# Out:
# Min value before which outlier exist: 4.0
# Max value after which outlier exist: 4.0

# %%
remove_outliers('Num_complaints')
# Out:
# Outliers of Num_complaints removed

# %%
outliers_of('number_plan_changes')
# Out:
# Min value before which outlier exist: -3.0
# Max value after which outlier exist: 5.0

# %%
remove_outliers('number_plan_changes')
# Out:
# Outliers of number_plan_changes removed

# %%
outliers_of('relocated')
# Out:
# Min value before which outlier exist: 0.0
# Max value after which outlier exist: 0.0

# %%
remove_outliers('relocated')
# Out:
# Outliers of relocated removed

# %%
outliers_of('monthly_bill')
# Out:
# Min value before which outlier exist: -87.0
# Max value after which outlier exist: 265.0

# %%
remove_outliers('monthly_bill')
# Out:
# Outliers of monthly_bill removed

# %%
outliers_of('technical_issues_per_month')
# Out:
# Min value before which outlier exist: 1.5
# Max value after which outlier exist: 5.5

# %%
remove_outliers('technical_issues_per_month')
# Out:
# Outliers of technical_issues_per_month removed

# %%
outliers_of('savings')
# Out:
# Min value before which outlier exist: -4.925000000000182
# Max value after which outlier exist: 919.6750000000002

# %%
remove_outliers('savings')
# Out:
# Outliers of savings removed

# %%
sns.countplot(df['active_cust'])
# Out:
# <AxesSubplot:xlabel='active_cust', ylabel='count'>

# %%
df['active_cust'].value_counts()
# Out:
# 1    36233
# 0    25669
# Name: active_cust, dtype: int64

# %%
df_dummy = df.drop(['Speed_test_result', 'income', 'expenditure'], axis = 1)
df_dummy.columns
# Out:
# Index(['active_cust', 'months_on_network', 'Num_complaints',
#        'number_plan_changes', 'relocated', 'monthly_bill',
#        'technical_issues_per_month', 'savings'],
#       dtype='object')

# %%
df_dummy = pd.get_dummies(df, columns = ['monthly_bill'])

# %%
df_dummy.head()
# Out:
#    active_cust  income  expenditure  months_on_network  Num_complaints  \
# 0            0    1586       1268.8                 85               4
# 1            0    1581       1264.8                 85               4
# 2            0    1594       1275.2                 82               4
# 3            0    1594       1275.2                 82               4
# 4            1    1609       1287.2                 80               4
#
#    number_plan_changes  relocated  technical_issues_per_month  \
# 0                    1          0                           4
# 1                    1          0                           4
# 2                    1          0                           4
# 3                    1          0                           4
# 4                    1          0                           4
#
#    Speed_test_result  savings  monthly_bill_a  monthly_bill_b  monthly_bill_c  \
# 0                 85    317.2               0               0               1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report, roc_auc_score,roc_curve,auc

# %%
accuracy_list = []
f1_list = []
roc_auc_list = []

# %%
def result(X, y, ts, rs, model):
    
    #train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=ts, random_state=rs)
    
    #scaling
    #sc = StandardScaler()
    #X_train = sc.fit_transform(X_train)
    #X_test = sc.transform(X_test)
    
    #fit on data
    model.fit(X_train, y_train)
    
    #prediction
    pred = model.predict(X_test)
    
    #performance of model
    print("Classification Report: \n", classification_report(y_test, pred))
    print("-" * 100)
    print()
    
    #accuracy of model
    acc = accuracy_score(y_test, pred)
    accuracy_list.append(acc)
    print("Accuracy Score: ", acc)
    print("-" * 100)
    print()

    #f1-score of model
    f1 = f1_score(y_test, pred)
    f1_list.append(f1)
    print("F1 Score: ", f1)
    print("-" * 100)
    print()

    #roc-auc curve of model
    fpr,tpr,threshold = roc_curve(y_test,pred)
    auc_value = auc(fpr,tpr)
    rocauc_score = roc_auc_score(y_test, pred)
    roc_auc_list.append(rocauc_score)
    plt.figure(figsize=(5,5),dpi=100)
    print("ROC-AUC Score: ", f1)
    print("-" * 100)
    print()
    plt.plot(fpr,tpr,linestyle='-',label = "(auc_value = %0.3f)" % auc_value)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
    print()
    
    #confusion matrix for model
    print("Confusion Matrix: ")
    plt.figure(figsize=(10, 5))
    sns.heatmap(confusion_matrix(y_test, pred), annot=True, fmt='g');
    plt.title('Confusion Matrix', fontsize=20)

# %%
y_dummy = df_dummy['active_cust']
x_dummy = df_dummy.drop(['active_cust'], axis = 1)

# %%
model = LogisticRegression()
result(x_dummy, y_dummy, 0.25, 42, model)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70     10394
#            1       0.77      0.86      0.81     14586
#
#     accuracy                           0.77     24980
#    macro avg       0.77      0.75      0.76     24980
# weighted avg       0.77      0.77      0.77     24980
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.7708166533226581
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.8135604259615071
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.8135604259615071
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %%
rf = RandomForestClassifier()
result(x_dummy, y_dummy, 0.25, 42, rf)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87     10394
#            1       0.90      0.92      0.91     14586
#
#     accuracy                           0.89     24980
#    macro avg       0.89      0.89      0.89     24980
# weighted avg       0.89      0.89      0.89     24980
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8926341072858287
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.9089242053789731
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.9089242053789731
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %%
from sklearn.utils import resample

# Separate Target Classes
df_0 = df[df.active_cust==0]
df_1 = df[df.active_cust==1]
 
# Upsample minority class
df_0_upsampled = resample(df_0, 
                                 replace=True,     # sample with replacement
                                 n_samples=36233,    # to match majority class
                                 random_state=123) # reproducible results

# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_1, df_0_upsampled])
 
# Display new class counts
df_upsampled.active_cust.value_counts()
# Out:
# 1    36233
# 0    36233
# Name: active_cust, dtype: int64

# %%
df_upsampled = df.drop(['Speed_test_result', 'income', 'expenditure'], axis = 1)
df_upsampled.columns
# Out:
# Index(['active_cust', 'months_on_network', 'Num_complaints',
#        'number_plan_changes', 'relocated', 'monthly_bill',
#        'technical_issues_per_month', 'savings'],
#       dtype='object')

# %%
df_upsampled = pd.get_dummies(df, columns = ['monthly_bill'])

# %%
y_unsampled = df_upsampled['active_cust']
x_unsampled = df_upsampled.drop(['active_cust'], axis = 1)

# %%
rf = RandomForestClassifier()
result(x_unsampled, y_unsampled, 0.25, 42, rf)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      6473
#            1       0.87      0.92      0.89      9003
#
#     accuracy                           0.87     15476
#    macro avg       0.87      0.87      0.87     15476
# weighted avg       0.87      0.87      0.87     15476
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.8742569139312484
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.8943768996960487
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.8943768996960487
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:

# %%
model = LogisticRegression()
result(x_dummy, y_dummy, 0.25, 42, model)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.52      0.59      6473
#            1       0.71      0.83      0.76      9003
#
#     accuracy                           0.70     15476
#    macro avg       0.70      0.67      0.68     15476
# weighted avg       0.70      0.70      0.69     15476
#
# ----------------------------------------------------------------------------------------------------
#
# Accuracy Score:  0.6992116826053244
# ----------------------------------------------------------------------------------------------------
#
# F1 Score:  0.7616609492601506
# ----------------------------------------------------------------------------------------------------
#
# ROC-AUC Score:  0.7616609492601506
# ----------------------------------------------------------------------------------------------------
# Confusion Matrix:
